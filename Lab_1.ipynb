# %% [markdown]
# <a href="https://colab.research.google.com/github/terrence-brian/Compiler-Construction/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Group members**
# * Regina Mbari - 121543
# * Kathlene Sumba - 120689
# * Natalie Aoya - 121600
# * Levi Kamara - 123558
# * Terrence Oyoo - 122846

# %% [markdown]
# 1. Flex
#   - Definition: Fast Lexical Analyzer Generator is a tool for generating prorams that perform pattern-matching on text. It therefore automates the conversion of a regular expression to an NFA and NFA to  DFA.
#   - Diagram:
#
#     ![image.png](data:image/png;base64,...)

# %%
#Flex code snippet
#This is a scanner that counts the number of lines

int line = 0;

%%
\n
++line;

%%

main()
{   
   yylex();
   printf( "Number of lines = %d \n", num_lines);
}

# %% [markdown]
# 2. Bison
#     - Definition: Bison is a general-purpose parser generator that uses LALR(lookahead LR) parser tables to convert an annotated context-free grammar into a DLR(Deterministic LR) or GLR(Generalized LR) parser. It can also generate IELR(Inadequacy elimination) or canonical LR parser tables.
#     - Diagram:
#     ![image.png](data:image/png;base64,...)

# %%
#Bison code snippet
/* Reverse polish notation calculator. */

# %{
#define YYSTYPE double
#include <math.h>
%}

# %token NUM

%% /* Grammar rules and actions follow */

# %% [markdown]
# 3. Lex
#     - Definition: Lex is a program tool that uses a configuration file to generate C source code that implements the lexer after reading an input stream that specifies the lexical analyzer.
#     - Diagram:![image.png](data:image/png;base64,...)

# %%
#Lex code snippet

# %option noyywrap

# %{
	#include <stdlib.h>
	#include <stdio.h>
%}
	
number [0-9]+
 
%%
 
{number} {printf("Found : %d\n",atoi(yytext));}
 
%%
 
int main()
{
	yylex();
	return 1;
}

# %% [markdown]
# 4. Yacc
#     - Definition: is the typical Unix operating system parser generator. It is an open source tool that creates parser code in the C programming language by taking the tokens as input and generates a parse tree as output.
#     - Diagram:![image.png](data:image/png;base64,...)

# %%
#Yacc code snippet
# %{
#include<stdio.h>

int regs[26];
int base;

%}

# %start list

# %union { int a; }
